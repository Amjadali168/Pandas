# %% [markdown]
# # `Visualizing Data`

# %%
import pandas as pd

# %%
df = pd.read_csv('pokemon.csv')

# %%
df[df['Type 1'] == 'Fire'].plot(x = "Name", y = ["Attack","Defense"])
# Out:
# <Axes: xlabel='Name'>
